# %% [markdown]
# # 1 Packages

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import tensorflow.keras.layers as tfl
from clearml import Task

from keras.layers import RandomFlip, RandomRotation, RandomCrop, RandomZoom, RandomContrast
from keras.src.callbacks import ReduceLROnPlateau, EarlyStopping
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix

# %%
task = Task.init(project_name='Architecture Style Classification', task_name='Imbalanced data with focal loss 2, random seed 123')
# Out:
# ClearML Task: created new task id=3de0078592434405aff726a2b76b2efb
# 2024-04-20 15:14:42,876 - clearml.Task - INFO - Storing jupyter notebook directly as code
# ClearML results page: https://app.clear.ml/projects/fb01ac3f8ec0442db15dd95b35c1dc10/experiments/3de0078592434405aff726a2b76b2efb/output/log

# %% [markdown]
# # 1.1 Create the Dataset and Split it into Training and Validation Sets

# %%
from pathlib import Path
import imghdr
from PIL import Image

data_dir = "D:/University/FinalDatasetSplited/train/21_st_Century, Blobitecture"
image_extensions = [".png", ".jpg"]

img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
for filepath in Path(data_dir).rglob("*"):
    if filepath.suffix.lower() in image_extensions:
        img_type = imghdr.what(filepath)
        img_type = imghdr.what(filepath)
        if img_type is None:
            print(filepath)
        elif img_type not in img_type_accepted_by_tf:
            print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %%
def is_image_corrupted(image_path):
    try:
        image = tf.io.read_file(image_path)
        image = tf.image.decode_jpeg(image, channels=3)
        return False  
    except tf.errors.InvalidArgumentError:
        return True  

root_directory = 'D:/University/FinalDatasetSplited/test'
corrupted_images = []
for root, dirs, files in os.walk(root_directory):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_path = os.path.join(root, file)
            if is_image_corrupted(image_path):
                try:
                    print(image_path)
                    img = Image.open(image_path)

                    print("fail here")
                    img_format = 'JPEG'
                    img.save(image_path, format=img_format)

                    print(f"Header fixed for {image_path}")
                except Exception as e:
                    print(f"Failed to fix header for {image_path}: {e}")

for image_path in corrupted_images:
    print("Corrupted image:", image_path)
# Out:
# D:/University/FinalDatasetSplited/test\21_st_Century, Neo-futurism architecture\03116.jpg
# Failed to fix header for D:/University/FinalDatasetSplited/test\21_st_Century, Neo-futurism architecture\03116.jpg: name 'Image' is not defined
# D:/University/FinalDatasetSplited/test\Classical, Roman Classical architecture\2382.jpg
# Failed to fix header for D:/University/FinalDatasetSplited/test\Classical, Roman Classical architecture\2382.jpg: name 'Image' is not defined
# D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Medieval Architecture\3288.jpg
# Failed to fix header for D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Medieval Architecture\3288.jpg: name 'Image' is not defined

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)
directory = 'D:/University/FinalDatasetSplited/train'
train_dataset = tf.keras.utils.image_dataset_from_directory(directory,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE,
                                                            validation_split=0.2,
                                                            label_mode='categorical',
                                                            subset='training',
                                                            seed=123)
validation_dataset = tf.keras.utils.image_dataset_from_directory(directory,
                                                                 shuffle=False,
                                                                 batch_size=BATCH_SIZE,
                                                                 image_size=IMG_SIZE,
                                                                 validation_split=0.2,
                                                                 subset='validation',
                                                                 label_mode='categorical',
                                                                 seed=123)
# Out:
# Found 16292 files belonging to 51 classes.
# Using 13034 files for training.
# Found 16292 files belonging to 51 classes.
# Using 3258 files for validation.

# %% [markdown]
# Represent data

# %%
class_names = train_dataset.class_names
plt.figure(figsize=(10, 10))
for images, labels in train_dataset.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        label = labels[i].numpy().astype("int")
        plt.title(class_names[np.where(label == 1)[0][0]])
        plt.axis("off")

# %% [markdown]
# # 2 Preprocess and Augment Training Data

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
def data_augmenter():
    data_augmentation = tf.keras.Sequential([])
    data_augmentation.add(RandomFlip('horizontal'))
    data_augmentation.add(RandomRotation(0.1))
    data_augmentation.add(RandomZoom(0.2))
    data_augmentation.add(RandomCrop(height=IMG_SIZE[0], width=IMG_SIZE[1]))
    data_augmentation.add(RandomContrast(factor=0.2))
    return data_augmentation

# %% [markdown]
# Augumented images

# %%
data_augmentation = data_augmenter()

# %%
IMG_SHAPE = IMG_SIZE + (3,)
base_model = tf.keras.applications.EfficientNetV2B0(input_shape=IMG_SHAPE,
                                                    include_top=True,
                                                    weights='imagenet')

# %%
preprocess_input = tf.keras.applications.efficientnet_v2.preprocess_input

# %% [markdown]
# # 3 Using EfficientNetB0V2

# %%
def arc_model(image_shape=IMG_SIZE, data_augmentation=data_augmenter()):
    input_shape = image_shape + (3,)
    base_model = tf.keras.applications.EfficientNetV2B0(input_shape=input_shape,
                                                        include_top=False,
                                                        weights='imagenet')
    base_model.trainable = False
    inputs = tf.keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(x)

    x = base_model(x, training=False)

    x = tf.keras.layers.GlobalMaxPooling2D()(x)

    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    # x = tf.keras.layers.BatchNormalization(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    # x = tf.keras.layers.Dropout(0.8)(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    # x = tf.keras.layers.BatchNormalization(x)
    # x = tf.keras.layers.Dropout(0.8)(x)
    x = tf.keras.layers.Dense(512, activation='relu')(x)
    # x = tf.keras.layers.Dropout(0.5)(x)
    # x = tf.keras.layers.BatchNormalization(x)
    x = tf.keras.layers.Dense(256, activation='relu')(x)
    # x = tf.keras.layers.BatchNormalization(x)
    # x = tf.keras.layers.Dropout(0.5)(x)

    outputs = tf.keras.layers.Dense(51, activation='softmax')(x)
    model = tf.keras.Model(inputs, outputs)

    return model

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=2, verbose=1, min_lr=0.00001)
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=0, restore_best_weights=True)

# %%
model2 = arc_model(IMG_SIZE, data_augmentation)
base_learning_rate = 0.001
model2.compile(optimizer=tf.keras.optimizers.Adam(),
               loss=tf.keras.losses.CategoricalFocalCrossentropy(),
               metrics=['accuracy'],
               )
initial_epochs = 50
history = model2.fit(train_dataset, validation_data=validation_dataset, epochs=initial_epochs, callbacks=[learning_rate_reduction, early_stopping])
# Out:
# Epoch 1/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 640s 2s/step - accuracy: 0.1476 - loss: 0.8032 - val_accuracy: 0.3177 - val_loss: 0.5827 - learning_rate: 0.0010
# Epoch 2/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 410s 992ms/step - accuracy: 0.2659 - loss: 0.5403 - val_accuracy: 0.3318 - val_loss: 0.5449 - learning_rate: 0.0010
# Epoch 3/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - accuracy: 0.2994 - loss: 0.4970 - val_accuracy: 0.3235 - val_loss: 0.5335 - learning_rate: 0.0010
# Epoch 4/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 407s 985ms/step - accuracy: 0.3235 - loss: 0.4725 - val_accuracy: 0.3781 - val_loss: 0.4906 - learning_rate: 0.0010
# Epoch 5/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 409s 989ms/step - accuracy: 0.3440 - loss: 0.4556 - val_accuracy: 0.3416 - val_loss: 0.4751 - learning_rate: 0.0010
# Epoch 6/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 0s 810ms/step - accuracy: 0.3582 - loss: 0.4370
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 409s 989ms/step - accuracy: 0.3581 - loss: 0.4370 - val_accuracy: 0.3732 - val_loss: 0.4562 - learning_rate: 0.0010
# Epoch 7/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 406s 983ms/step - accuracy: 0.4001 - loss: 0.4091 - val_accuracy: 0.4036 - val_loss: 0.4410 - learning_rate: 5.0000e-04
# Epoch 8/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 417s 1s/step - accuracy: 0.3902 - loss: 0.3960 - val_accuracy: 0.4162 - val_loss: 0.4300 - learning_rate: 5.0000e-04
# Epoch 9/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 435s 1s/step - accuracy: 0.4113 - loss: 0.3880 - val_accuracy: 0.4273 - val_loss: 0.4066 - learning_rate: 5.0000e-04
# Epoch 10/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 425s 1s/step - accuracy: 0.4112 - loss: 0.3793 - val_accuracy: 0.4285 - val_loss: 0.4097 - learning_rate: 5.0000e-04
# Epoch 11/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 411s 993ms/step - accuracy: 0.4139 - loss: 0.3783 - val_accuracy: 0.4245 - val_loss: 0.4068 - learning_rate: 5.0000e-04
# Epoch 12/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 416s 1s/step - accuracy: 0.4205 - loss: 0.3689 - val_accuracy: 0.4469 - val_loss: 0.4012 - learning_rate: 5.0000e-04
# Epoch 13/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 407s 985ms/step - accuracy: 0.4221 - loss: 0.3660 - val_accuracy: 0.4669 - val_loss: 0.3712 - learning_rate: 5.0000e-04
# Epoch 14/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 415s 1s/step - accuracy: 0.4287 - loss: 0.3588 - val_accuracy: 0.4389 - val_loss: 0.4029 - learning_rate: 5.0000e-04
# Epoch 15/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 0s 807ms/step - accuracy: 0.4363 - loss: 0.3536
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 405s 979ms/step - accuracy: 0.4363 - loss: 0.3536 - val_accuracy: 0.4500 - val_loss: 0.3941 - learning_rate: 5.0000e-04
# Epoch 16/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 404s 978ms/step - accuracy: 0.4537 - loss: 0.3399 - val_accuracy: 0.4840 - val_loss: 0.3600 - learning_rate: 2.5000e-04
# Epoch 17/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 404s 978ms/step - accuracy: 0.4677 - loss: 0.3301 - val_accuracy: 0.4954 - val_loss: 0.3508 - learning_rate: 2.5000e-04
# Epoch 18/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 406s 981ms/step - accuracy: 0.4621 - loss: 0.3269 - val_accuracy: 0.4883 - val_loss: 0.3556 - learning_rate: 2.5000e-04
# Epoch 19/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 406s 982ms/step - accuracy: 0.4576 - loss: 0.3312 - val_accuracy: 0.4966 - val_loss: 0.3440 - learning_rate: 2.5000e-04
# Epoch 20/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 407s 986ms/step - accuracy: 0.4715 - loss: 0.3211 - val_accuracy: 0.4917 - val_loss: 0.3496 - learning_rate: 2.5000e-04
# Epoch 21/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 405s 979ms/step - accuracy: 0.4676 - loss: 0.3227 - val_accuracy: 0.5034 - val_loss: 0.3321 - learning_rate: 2.5000e-04
# Epoch 22/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 405s 979ms/step - accuracy: 0.4745 - loss: 0.3142 - val_accuracy: 0.5009 - val_loss: 0.3363 - learning_rate: 2.5000e-04
# Epoch 23/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 410s 993ms/step - accuracy: 0.4760 - loss: 0.3168 - val_accuracy: 0.5114 - val_loss: 0.3387 - learning_rate: 2.5000e-04
# Epoch 24/50
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 405s 980ms/step - accuracy: 0.4780 - loss: 0.3156 - val_accuracy: 0.4936 - val_loss: 0.3471 - learning_rate: 2.5000e-04

# %% [markdown]
# Results

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss'][:25]
val_loss = history.history['val_loss'][:25]
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()), 1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0, 4.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
from tensorflow.keras import layers

base_model = model2
model2.trainable = True

fine_tune_at = -10

# for layer in base_model.layers[:fine_tune_at]:
#     if not isinstance(layer, layers.BatchNormalization):
#         layer.trainable = False
for layer in model2.layers[-20:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True
loss_function = tf.keras.losses.CategoricalFocalCrossentropy()
# Define an Adam optimizer with a learning rate of 0.1 * base_learning_rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.1 * base_learning_rate)
# Use accuracy as evaluation metric
metrics = ['accuracy']

model2.compile(loss=loss_function,
               optimizer=optimizer,
               metrics=metrics)

fine_tune_epochs = 50
total_epochs = initial_epochs + fine_tune_epochs

history_fine = model2.fit(train_dataset,
                          epochs=total_epochs,
                          initial_epoch=history.epoch[-1],
                          validation_data=validation_dataset,
                          callbacks=[learning_rate_reduction, early_stopping]
                          )
# Out:
# Epoch 24/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1178s 3s/step - accuracy: 0.3439 - loss: 0.4851 - val_accuracy: 0.4859 - val_loss: 0.3667 - learning_rate: 1.0000e-04
# Epoch 25/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1127s 3s/step - accuracy: 0.4907 - loss: 0.3106 - val_accuracy: 0.5141 - val_loss: 0.3341 - learning_rate: 1.0000e-04
# Epoch 26/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1127s 3s/step - accuracy: 0.5305 - loss: 0.2684 - val_accuracy: 0.5602 - val_loss: 0.2892 - learning_rate: 1.0000e-04
# Epoch 27/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1129s 3s/step - accuracy: 0.5533 - loss: 0.2442 - val_accuracy: 0.5758 - val_loss: 0.2674 - learning_rate: 1.0000e-04
# Epoch 28/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1129s 3s/step - accuracy: 0.5751 - loss: 0.2266 - val_accuracy: 0.6007 - val_loss: 0.2411 - learning_rate: 1.0000e-04
# Epoch 29/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1131s 3s/step - accuracy: 0.5964 - loss: 0.2077 - val_accuracy: 0.6034 - val_loss: 0.2392 - learning_rate: 1.0000e-04
# Epoch 30/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1127s 3s/step - accuracy: 0.6055 - loss: 0.1958 - val_accuracy: 0.6357 - val_loss: 0.2131 - learning_rate: 1.0000e-04
# Epoch 31/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1130s 3s/step - accuracy: 0.6295 - loss: 0.1819 - val_accuracy: 0.6387 - val_loss: 0.2092 - learning_rate: 1.0000e-04
# Epoch 32/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1129s 3s/step - accuracy: 0.6337 - loss: 0.1684 - val_accuracy: 0.6630 - val_loss: 0.1818 - learning_rate: 1.0000e-04
# Epoch 33/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1128s 3s/step - accuracy: 0.6565 - loss: 0.1548 - val_accuracy: 0.6624 - val_loss: 0.1791 - learning_rate: 1.0000e-04
# Epoch 34/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1125s 3s/step - accuracy: 0.6680 - loss: 0.1485 - val_accuracy: 0.6811 - val_loss: 0.1643 - learning_rate: 1.0000e-04
# Epoch 35/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1129s 3s/step - accuracy: 0.6805 - loss: 0.1358 - val_accuracy: 0.7056 - val_loss: 0.1489 - learning_rate: 1.0000e-04
# Epoch 36/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1136s 3s/step - accuracy: 0.6843 - loss: 0.1314 - val_accuracy: 0.7139 - val_loss: 0.1490 - learning_rate: 1.0000e-04
# Epoch 37/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1131s 3s/step - accuracy: 0.6967 - loss: 0.1213 - val_accuracy: 0.7225 - val_loss: 0.1470 - learning_rate: 1.0000e-04
# Epoch 38/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1129s 3s/step - accuracy: 0.7070 - loss: 0.1141 - val_accuracy: 0.7348 - val_loss: 0.1267 - learning_rate: 1.0000e-04
# Epoch 39/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1130s 3s/step - accuracy: 0.7200 - loss: 0.1086 - val_accuracy: 0.7489 - val_loss: 0.1200 - learning_rate: 1.0000e-04
# Epoch 40/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1127s 3s/step - accuracy: 0.7321 - loss: 0.1020 - val_accuracy: 0.7360 - val_loss: 0.1230 - learning_rate: 1.0000e-04
# Epoch 41/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1128s 3s/step - accuracy: 0.7339 - loss: 0.0972 - val_accuracy: 0.7554 - val_loss: 0.1253 - learning_rate: 1.0000e-04
# Epoch 42/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1126s 3s/step - accuracy: 0.7394 - loss: 0.0946 - val_accuracy: 0.7600 - val_loss: 0.1107 - learning_rate: 1.0000e-04
# Epoch 43/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1128s 3s/step - accuracy: 0.7559 - loss: 0.0859 - val_accuracy: 0.7741 - val_loss: 0.1008 - learning_rate: 1.0000e-04
# Epoch 44/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1127s 3s/step - accuracy: 0.7511 - loss: 0.0856 - val_accuracy: 0.7830 - val_loss: 0.1000 - learning_rate: 1.0000e-04
# Epoch 45/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1131s 3s/step - accuracy: 0.7612 - loss: 0.0791 - val_accuracy: 0.7827 - val_loss: 0.1027 - learning_rate: 1.0000e-04
# Epoch 46/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1128s 3s/step - accuracy: 0.7722 - loss: 0.0761 - val_accuracy: 0.7977 - val_loss: 0.0952 - learning_rate: 1.0000e-04
# Epoch 47/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1128s 3s/step - accuracy: 0.7816 - loss: 0.0692 - val_accuracy: 0.7990 - val_loss: 0.0982 - learning_rate: 1.0000e-04
# Epoch 48/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1129s 3s/step - accuracy: 0.7888 - loss: 0.0671 - val_accuracy: 0.7891 - val_loss: 0.1024 - learning_rate: 1.0000e-04
# Epoch 49/100
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1134s 3s/step - accuracy: 0.7876 - loss: 0.0657 - val_accuracy: 0.8054 - val_loss: 0.0958 - learning_rate: 1.0000e-04

# %% [markdown]
# Results

# %%
acc
# Out:
# [0.0,
#  0.20937548577785492,
#  0.2850237786769867,
#  0.30980512499809265,
#  0.33435630798339844,
#  0.3721037209033966,
#  0.3856835961341858,
#  0.3953506350517273,
#  0.4047107696533203,
#  0.408623605966568,
#  0.4212060868740082,
#  0.4229706823825836,
#  0.4498235285282135,
#  0.46025779843330383,
#  0.4548105001449585,
#  0.4740678369998932,
#  0.4776737689971924,
#  0.4780573844909668,
#  0.48680374026298523,
#  0.4894123077392578,
#  0.48994937539100647,
#  0.49056315422058105,
#  0.49716126918792725,
#  0.4913303554058075,
#  0.49923276901245117,
#  0.4112321734428406,
#  0.5086696147918701,
#  0.5400490760803223,
#  0.5705845952033997,
#  0.5904557108879089,
#  0.611170768737793,
#  0.6321160197257996,
#  0.6514500379562378,
#  0.6690194606781006,
#  0.6810649037361145,
#  0.7027006149291992,
#  0.7160503268241882,
#  0.7271750569343567,
#  0.7465858459472656,
#  0.7577105760574341,
#  0.7686818838119507,
#  0.7793463468551636,
#  0.7914684414863586,
#  0.7974528074264526,
#  0.8089611530303955,
#  0.8189350962638855,
#  0.8291391730308533,
#  0.846785306930542,
#  0.8609022498130798,
#  0.8591376543045044,
#  0.8669633269309998,
#  0.8710296154022217,
#  0.4112321734428406,
#  0.5086696147918701,
#  0.5400490760803223,
#  0.5705845952033997,
#  0.5904557108879089,
#  0.611170768737793,
#  0.6321160197257996,
#  0.6514500379562378,
#  0.6690194606781006,
#  0.6810649037361145,
#  0.7027006149291992,
#  0.7160503268241882,
#  0.7271750569343567,
#  0.7465858459472656,
#  0.7577105760574341,
#  0.7686818838119507,
#  0.7793463468551636,
#  0.7914684414863586,
#  0.7974528074264526,
#  0.8089611530303955,
#  0.8189350962638855,
#  0.8291391730308533,
#  0.846785306930542,
#  0.8609022498130798,
#  0.8591376543045044,
#  0.8669633269309998,
#  0.8710296154022217,
#  0.4112321734428406,
#  0.5086696147918701,
#  0.5400490760803223,
#  0.5705845952033997,
#  0.5904557108879089,
#  0.611170768737793,
#  0.6321160197257996,
#  0.6514500379562378,
#  0.6690194606781006,
#  0.6810649037361145,
#  0.7027006149291992,
#  0.7160503268241882,
#  0.7271750569343567,
#  0.7465858459472656,
#  0.7577105760574341,
#  0.7686818838119507,
#  0.7793463468551636,
#  0.7914684414863586,
#  0.7974528074264526,
#  0.8089611530303955,
#  0.8189350962638855,
#  0.8291391730308533,
#  0.846785306930542,
#  0.8609022498130798,
#  0.8591376543045044,
#  0.8669633269309998,
#  0.8710296154022217,
#  0.4112321734428406,
#  0.5086696147918701,
#  0.5400490760803223,
#  0.5705845952033997,
#  0.5904557108879089,
#  0.611170768737793,
#  0.6321160197257996,
#  0.6514500379562378,
#  0.6690194606781006,
#  0.6810649037361145,
#  0.7027006149291992,
#  0.7160503268241882,
#  0.7271750569343567,
#  0.7465858459472656,
#  0.7577105760574341,
#  0.7686818838119507,
#  0.7793463468551636,
#  0.7914684414863586,
#  0.7974528074264526,
#  0.8089611530303955,
#  0.8189350962638855,
#  0.8291391730308533,
#  0.846785306930542,
#  0.8609022498130798,
#  0.8591376543045044,
#  0.8669633269309998,
#  0.8710296154022217]

# %%
acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0, 1])
plt.plot([23, 23],
         plt.ylim())
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 4.0])
plt.plot([23, 23],
         plt.ylim())
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
base_model = model2
base_model.trainable = True

fine_tune_at = -10

# for layer in base_model.layers[:fine_tune_at]:
#     if not isinstance(layer, layers.BatchNormalization):
#         layer.trainable = False
for layer in base_model.layers[-20:]:
    if not isinstance(layer, layers.BatchNormalization):
        layer.trainable = True
loss_function = tf.keras.losses.CategoricalCrossentropy()
# Define an Adam optimizer with a learning rate of 0.1 * base_learning_rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.1 * base_learning_rate)
# Use accuracy as evaluation metric
metrics = ['accuracy']

base_model.compile(loss=loss_function,
               optimizer=optimizer,
               metrics=metrics)

fine_tune_epochs1 = 50
total_epochs = initial_epochs + fine_tune_epochs + fine_tune_epochs1

history_fine = base_model.fit(train_dataset,
                          epochs=total_epochs,
                          initial_epoch=history_fine.epoch[-1],
                          validation_data=validation_dataset,
                          callbacks=[learning_rate_reduction, early_stopping]
                          )
# Out:
# Epoch 50/150
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1215s 3s/step - accuracy: 0.8369 - loss: 0.4532 - val_accuracy: 0.8122 - val_loss: 0.6455 - learning_rate: 1.0000e-04
# Epoch 51/150
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1128s 3s/step - accuracy: 0.8504 - loss: 0.4269 - val_accuracy: 0.8303 - val_loss: 0.6052 - learning_rate: 1.0000e-04
# Epoch 52/150
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1129s 3s/step - accuracy: 0.8574 - loss: 0.4116 - val_accuracy: 0.8174 - val_loss: 0.6465 - learning_rate: 1.0000e-04
# Epoch 53/150
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8552 - loss: 0.4178
# Epoch 53: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1127s 3s/step - accuracy: 0.8552 - loss: 0.4178 - val_accuracy: 0.8106 - val_loss: 0.6955 - learning_rate: 1.0000e-04
# Epoch 54/150
# 408/408 ━━━━━━━━━━━━━━━━━━━━ 1126s 3s/step - accuracy: 0.8788 - loss: 0.3484 - val_accuracy: 0.8171 - val_loss: 0.6475 - learning_rate: 5.0000e-05

# %% [markdown]
# # Evaluate the results

# %%
test_directory = 'D:/University/FinalDatasetSplited/test'
test_dataset = tf.keras.utils.image_dataset_from_directory(test_directory,
                                                            shuffle=False,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE,
                                                            label_mode='categorical',
                                                            seed=42)
#test_dataset = test_dataset.map(lambda x, y: (preprocess_input(x), y))
# Out:
# Found 1808 files belonging to 51 classes.

# %%
loss, accuracy = model2.evaluate(train_dataset, batch_size=BATCH_SIZE, verbose=0)
print('Train Loss:', loss, 'Train Accuracy:', accuracy)
# Out:
# Train Loss: 0.04298235476016998 Train Accuracy: 0.8426423072814941

# %%
loss, accuracy = model2.evaluate(validation_dataset, batch_size=BATCH_SIZE, verbose=0)
print('Validation Loss:', loss, 'Validation Accuracy:', accuracy)
# Out:
# Validation Loss: 0.09524814784526825 Validation Accuracy: 0.7977286577224731

# %%
loss, accuracy = model2.evaluate(test_dataset, batch_size=BATCH_SIZE, verbose=0)
print('Test Loss:', loss, 'Test Accuracy:', accuracy)
# Out:
# Test Loss: 0.2760755717754364 Test Accuracy: 0.622787594795227

# %%
from sklearn.metrics import classification_report

prediction = model2.predict(test_dataset, batch_size=BATCH_SIZE, verbose=1)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 81s 1s/step

# %%
true_labels = []
for images, labels in test_dataset:
    true_labels.extend(np.argmax(labels, axis=1))

predicted_labels = np.argmax(prediction, axis=1)

print(classification_report(true_labels, predicted_labels, target_names=class_names))
# Out:
#                                                                 precision    recall  f1-score   support
#
#                                    21_st_Century, Blobitecture       0.62      0.70      0.65        23
#                                21_st_Century, Deconstructivism       0.60      0.79      0.68        34
#                                21_st_Century, Eco-architecture       0.93      0.52      0.67        25
#                       21_st_Century, Neo-futurism architecture       0.71      0.45      0.56        11
#                         21_st_Century, Postmodern architecture       0.54      0.62      0.58        32
#                           Baroque, Andean Baroque Architecture       0.50      0.33      0.40        12
#                                  Baroque, Baroque architecture       0.53      0.59      0.56        46
#                       Baroque, Earthquake Baroque Architecture       0.25      0.08      0.12        13
#                                   Baroque, Rococo Architecture       0.50      0.33      0.40        12
#                          Baroque, Russian Baroque Architecture       0.29      0.12      0.17        17
#                         Baroque, Sicilian Baroque Architecture       0.60      0.46      0.52        13
#                                     Baroque, Ukrainian Baroque       0.79      0.55      0.65        42
#                             Classical, Achaemenid architecture       0.82      0.85      0.84        39
#                       Classical, Ancient Egyptian architecture       0.90      0.88      0.89        41
#                               Classical, Herodian architecture       0.80      0.57      0.67        14
#                        Classical, Roman Classical architecture       0.48      0.92      0.63        12
#               Early_Christian_Medieval, Byzantine architecture       0.65      0.65      0.65        31
#                  Early_Christian_Medieval, Gothic architecture       0.65      0.76      0.70       211
#                Early_Christian_Medieval, Medieval Architecture       0.50      0.08      0.14        12
#                               Early_Christian_Medieval, Norman       0.60      0.45      0.51        20
#              Early_Christian_Medieval, Romanesque architecture       0.52      0.54      0.53       153
#         Early_Christian_Medieval, Venetian Gothic Architecture       0.62      0.62      0.62        13
#                  Eclecticism, American Foursquare architecture       0.63      0.67      0.65        36
#                          Eclecticism, American craftsman style       0.59      0.53      0.56        36
#                          Eclecticism, Art Nouveau architecture       0.58      0.68      0.63        62
#                               Modernism, Art Deco architecture       0.58      0.63      0.61        57
#                                Modernism, Bauhaus architecture       0.48      0.62      0.54        32
#                                           Modernism, Brutalism       0.64      0.74      0.68        34
#                         Modernism, Chicago school architecture       0.73      0.68      0.70        28
#                                 Modernism, International style       0.58      0.60      0.59        42
#                       Modernism, Ukrainian modern architecture       0.70      0.50      0.58        14
#                         Neoclassicism, Beaux-Arts architecture       0.76      0.52      0.62        42
#                      Neoclassicism, Greek Revival architecture       0.64      0.79      0.71        52
#                          Neoclassicism, Palladian architecture       0.65      0.44      0.53        34
#                                    Neoclassicism, Stalin Ampir       0.53      0.69      0.60        29
#                                           Novelty architecture       0.92      0.87      0.89        38
#             Renaissance_and_Colonialism, Colonial architecture       0.50      0.58      0.54        48
#   Renaissance_and_Colonialism, French Renaissance Architecture       1.00      0.20      0.33        15
#             Renaissance_and_Colonialism, Georgian architecture       0.54      0.53      0.53        38
#            Renaissance_and_Colonialism, Mannerist Architecture       0.20      0.15      0.17        13
# Renaissance_and_Colonialism, Northern Renaissance Architecture       0.17      0.27      0.21        11
#     Renaissance_and_Colonialism, Spanish Colonial Architecture       0.55      0.35      0.43        17
#  Renaissance_and_Colonialism, Spanish Renaissance Architecture       0.31      0.31      0.31        13
#                       Revivalism, Colonial Revival archtecture       0.44      0.18      0.26        22
#                             Revivalism, Edwardian architecture       0.53      0.29      0.37        28
#                           Revivalism, Orientalism Architecture       0.40      0.18      0.25        11
#                            Revivalism, Queen Anne architecture       0.78      0.86      0.82        72
#                       Revivalism, Russian Revival architecture       0.64      0.80      0.71        35
#                         Revivalism, Tudor Revival architecture       0.69      0.80      0.74        45
#                              Ukrainian classicism architecture       0.58      0.61      0.60        41
#                                    Ukrainian folk architecture       0.91      0.78      0.84        37
#
#                                                       accuracy                           0.62      1808
#                                                      macro avg       0.60      0.54      0.55      1808
#                                                   weighted avg       0.63      0.62      0.61      1808

# %%
conf_matrix = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(15, 15))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
model_name = "model_focal_v1"
model_json = model2.to_json()
with open(f"{model_name}_architecture.json", "w") as json_file:
    json_file.write(model_json)

# Save the model weights to HDF5 file
model2.save_weights(f"{model_name}.weights.h5")

# %%
tf.keras.models.save_model(model2, f"{model_name}.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 tf.keras.models.save_model(model2, f"{model_name}.h5")
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\clearml\binding\frameworks\__init__.py:36, in _patched_call.<locals>._inner_patch(*args, **kwargs)
#      34     ret = patched_fn(original_fn, *args, **kwargs)
#      35 except Exception as ex:
# ---> 36     raise ex
#      37 finally:
#      38     try:
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\clearml\binding\frameworks\__init__.py:34, in _patched_call.<locals>._inner_patch(*args, **kwargs)
#      32 ret = None
#      33 try:
# ---> 34     ret = patched_fn(original_fn, *args, **kwargs)
#      35 except Exception as ex:
#      36     raise ex
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\clearml\binding\frameworks\tensorflow_bind.py:1918, in PatchKerasModelIO._save_model(original_fn, model, filepath, *args, **kwargs)
#    1916 @staticmethod
#    1917 def _save_model(original_fn, model, filepath, *args, **kwargs):
# -> 1918     original_fn(model, filepath, *args, **kwargs)
#    1919     if PatchKerasModelIO._current_task:
#    1920         PatchKerasModelIO._update_outputmodel(model, filepath)
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\keras\src\saving\saving_api.py:102, in save_model(model, filepath, overwrite, **kwargs)
#     100     saving_lib.save_model(model, filepath)
#     101 elif str(filepath).endswith((".h5", ".hdf5")):
# --> 102     legacy_h5_format.save_model_to_hdf5(
#     103         model, filepath, overwrite, include_optimizer
#     104     )
#     105 else:
#     106     raise ValueError(
#     107         "Invalid filepath extension for saving. "
#     108         "Please add either a `.keras` extension for the native Keras "
#    (...)
#     112         f"Received: filepath={filepath}."
#     113     )
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:51, in save_model_to_hdf5(model, filepath, overwrite, include_optimizer)
#      49 try:
#      50     with saving_options.keras_option_scope(use_legacy_config=True):
# ---> 51         model_metadata = saving_utils.model_metadata(
#      52             model, include_optimizer
#      53         )
#      54         for k, v in model_metadata.items():
#      55             if isinstance(v, (dict, list, tuple)):
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\keras\src\legacy\saving\saving_utils.py:99, in model_metadata(model, include_optimizer, require_config)
#      97 model_config = {"class_name": model.__class__.__name__}
#      98 try:
# ---> 99     model_config["config"] = model.get_config()
#     100 except NotImplementedError as e:
#     101     if require_config:
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\keras\src\models\functional.py:402, in Functional.get_config(self)
#     399 if global_state.get_global_attribute("use_legacy_config", False):
#     400     # Legacy format serialization used for H5 and SavedModel
#     401     serialize_obj_fn = legacy_serialization.serialize_keras_object
# --> 402 layer_config = serialize_obj_fn(operation)
#     403 layer_config["name"] = operation.name
#     404 layer_config["inbound_nodes"] = filtered_inbound_nodes
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\keras\src\legacy\saving\serialization.py:294, in serialize_keras_object(instance)
#     292 name = object_registration.get_registered_name(instance.__class__)
#     293 try:
# --> 294     config = instance.get_config()
#     295 except NotImplementedError as e:
#     296     if _SKIP_FAILED_SERIALIZATION:
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\keras\src\models\sequential.py:307, in Sequential.get_config(self)
#     305 config = Model.get_config(self)
#     306 config["name"] = self.name
# --> 307 config["layers"] = copy.deepcopy(layer_configs)
#     308 if self._functional is not None:
#     309     config["build_input_shape"] = self._layers[0].batch_shape
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:211, in _deepcopy_tuple(x, memo, deepcopy)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:211, in <listcomp>(.0)
#     210 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 211     y = [deepcopy(a, memo) for a in x]
#     212     # We're not going to put the tuple in the memo, but it's still important we
#     213     # check for it, in case the tuple contains recursive mutable structures.
#     214     try:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:206, in _deepcopy_list(x, memo, deepcopy)
#     204 append = y.append
#     205 for a in x:
# --> 206     append(deepcopy(a, memo))
#     207 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:172, in deepcopy(x, memo, _nil)
#     170                 y = x
#     171             else:
# --> 172                 y = _reconstruct(x, memo, *rv)
#     174 # If is its own copy, don't memoize.
#     175 if y is not x:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:271, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     269 if state is not None:
#     270     if deep:
# --> 271         state = deepcopy(state, memo)
#     272     if hasattr(y, '__setstate__'):
#     273         y.__setstate__(state)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:231, in _deepcopy_dict(x, memo, deepcopy)
#     229 memo[id(x)] = y
#     230 for key, value in x.items():
# --> 231     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     232 return y
#
# File ~\AppData\Local\Programs\Python\Python310\lib\copy.py:161, in deepcopy(x, memo, _nil)
#     159 reductor = getattr(x, "__reduce_ex__", None)
#     160 if reductor is not None:
# --> 161     rv = reductor(4)
#     162 else:
#     163     reductor = getattr(x, "__reduce__", None)
#
# TypeError: cannot pickle 'module' object

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model2)
tflite_model = converter.convert()

# Save the TFLite model to a file
with open('models/model_focal_v1.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 2
#       1 converter = tf.lite.TFLiteConverter.from_keras_model(model2)
# ----> 2 tflite_model = converter.convert()
#       4 # Save the TFLite model to a file
#       5 with open('models/model_focal_v1.tflite', 'wb') as f:
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\tensorflow\lite\python\lite.py:1175, in _export_metrics.<locals>.wrapper(self, *args, **kwargs)
#    1172 @functools.wraps(convert_func)
#    1173 def wrapper(self, *args, **kwargs):
#    1174   # pylint: disable=protected-access
# -> 1175   return self._convert_and_export_metrics(convert_func, *args, **kwargs)
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\tensorflow\lite\python\lite.py:1129, in TFLiteConverterBase._convert_and_export_metrics(self, convert_func, *args, **kwargs)
#    1127 self._save_conversion_params_metric()
#    1128 start_time = time.process_time()
# -> 1129 result = convert_func(self, *args, **kwargs)
#    1130 elapsed_time_ms = (time.process_time() - start_time) * 1000
#    1131 if result:
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\tensorflow\lite\python\lite.py:1641, in TFLiteKerasModelConverterV2.convert(self)
#    1637 if saved_model_convert_result:
#    1638   return saved_model_convert_result
#    1640 graph_def, input_tensors, output_tensors, frozen_func = (
# -> 1641     self._freeze_keras_model()
#    1642 )
#    1644 graph_def = self._optimize_tf_model(
#    1645     graph_def, input_tensors, output_tensors, frozen_func
#    1646 )
#    1648 return super(TFLiteKerasModelConverterV2, self).convert(
#    1649     graph_def, input_tensors, output_tensors
#    1650 )
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\tensorflow\lite\python\convert_phase.py:215, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     213 except Exception as error:
#     214   report_error_message(str(error))
# --> 215   raise error from None
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\tensorflow\lite\python\convert_phase.py:205, in convert_phase.<locals>.actual_decorator.<locals>.wrapper(*args, **kwargs)
#     202 @functools.wraps(func)
#     203 def wrapper(*args, **kwargs):
#     204   try:
# --> 205     return func(*args, **kwargs)
#     206   except ConverterError as converter_error:
#     207     if converter_error.errors:
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\tensorflow\lite\python\lite.py:1582, in TFLiteKerasModelConverterV2._freeze_keras_model(self)
#    1573 # If the model's call is not a `tf.function`, then we need to first get its
#    1574 # input signature from `model_input_signature` method. We can't directly
#    1575 # call `trace_model_call` because otherwise the batch dimension is set
#    1576 # to None.
#    1577 # Once we have better support for dynamic shapes, we can remove this.
#    1578 if not isinstance(self._keras_model.call, _def_function.Function):
#    1579   # Pass `keep_original_batch_size=True` will ensure that we get an input
#    1580   # signature including the batch dimension specified by the user.
#    1581   # TODO(b/169898786): Use the Keras public API when TFLite moves out of TF
# -> 1582   input_signature = _model_input_signature(
#    1583       self._keras_model, keep_original_batch_size=True
#    1584   )
#    1586 # TODO(b/169898786): Use the Keras public API when TFLite moves out of TF
#    1587 func = _trace_model_call(self._keras_model, input_signature)
#
# File ~\DataspellProjects\Thesis_final_models\venv\lib\site-packages\tensorflow\lite\python\tflite_keras_util.py:84, in model_input_signature(model, keep_original_batch_size)
#      82   input_specs = input_specs[0][0]
#      83 else:
# ---> 84   input_specs = model._get_save_spec(  # pylint: disable=protected-access
#      85       dynamic_batch=not keep_original_batch_size)
#      86   if input_specs is None:
#      87     return None
#
# AttributeError: 'Functional' object has no attribute '_get_save_spec'

# %%
for epoch, history in enumerate(acc):
    task.get_logger().report_scalar("training", "accuracy", history, iteration=epoch)
for epoch, history in enumerate(val_loss):
    task.get_logger().report_scalar("validation", "loss", history, iteration=epoch)
for epoch, history in enumerate(val_acc):
    task.get_logger().report_scalar("validation", "accuracy", history, iteration=epoch)

# %%
task.upload_artifact(artifact_object="model_focal_v1.h5", name="focal")
# Out:
# True

# %%
task.upload_artifact(artifact_object="model_focal_v1_architecture.json", name="focal_architecture")
# Out:
# True

# %%
task.upload_artifact(artifact_object="model_focal_v1.weights.h5", name="focal_weights")
# Out:
# True

# %%
from keras.models import model_from_json
model_name = "model_focal_v1"
model_architecture_path = f"{model_name}_architecture.json"
with open(model_architecture_path, "r") as json_file:
    loaded_model_json = json_file.read()
loaded_model = model_from_json(loaded_model_json)

# Load the saved model weights
loaded_model.load_weights(f"{model_name}.weights.h5")

# %%
prediction = loaded_model.predict(test_dataset, batch_size=BATCH_SIZE, verbose=1)
# Out:
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step

# %%
true_labels = []
for images, labels in test_dataset:
    true_labels.extend(np.argmax(labels, axis=1))

predicted_labels = np.argmax(prediction, axis=1)

print(classification_report(true_labels, predicted_labels, target_names=test_dataset.class_names))
# Out:
#                                                                 precision    recall  f1-score   support
#
#                                    21_st_Century, Blobitecture       0.54      0.61      0.57        23
#                                21_st_Century, Deconstructivism       0.65      0.65      0.65        34
#                                21_st_Century, Eco-architecture       0.94      0.68      0.79        25
#                       21_st_Century, Neo-futurism architecture       0.57      0.36      0.44        11
#                         21_st_Century, Postmodern architecture       0.56      0.59      0.58        32
#                           Baroque, Andean Baroque Architecture       0.38      0.25      0.30        12
#                                  Baroque, Baroque architecture       0.59      0.57      0.58        46
#                       Baroque, Earthquake Baroque Architecture       0.11      0.08      0.09        13
#                                   Baroque, Rococo Architecture       0.40      0.17      0.24        12
#                          Baroque, Russian Baroque Architecture       0.21      0.18      0.19        17
#                         Baroque, Sicilian Baroque Architecture       0.62      0.38      0.48        13
#                                     Baroque, Ukrainian Baroque       0.70      0.67      0.68        42
#                             Classical, Achaemenid architecture       0.78      0.82      0.80        39
#                       Classical, Ancient Egyptian architecture       0.86      0.93      0.89        41
#                               Classical, Herodian architecture       0.67      0.57      0.62        14
#                        Classical, Roman Classical architecture       0.42      0.67      0.52        12
#               Early_Christian_Medieval, Byzantine architecture       0.60      0.68      0.64        31
#                  Early_Christian_Medieval, Gothic architecture       0.70      0.76      0.73       211
#                Early_Christian_Medieval, Medieval Architecture       0.10      0.08      0.09        12
#                               Early_Christian_Medieval, Norman       0.80      0.40      0.53        20
#              Early_Christian_Medieval, Romanesque architecture       0.56      0.64      0.60       153
#         Early_Christian_Medieval, Venetian Gothic Architecture       0.57      0.62      0.59        13
#                  Eclecticism, American Foursquare architecture       0.64      0.69      0.67        36
#                          Eclecticism, American craftsman style       0.61      0.61      0.61        36
#                          Eclecticism, Art Nouveau architecture       0.68      0.87      0.76        62
#                               Modernism, Art Deco architecture       0.66      0.67      0.66        57
#                                Modernism, Bauhaus architecture       0.50      0.53      0.52        32
#                                           Modernism, Brutalism       0.53      0.82      0.64        34
#                         Modernism, Chicago school architecture       0.90      0.68      0.78        28
#                                 Modernism, International style       0.60      0.62      0.61        42
#                       Modernism, Ukrainian modern architecture       0.64      0.50      0.56        14
#                         Neoclassicism, Beaux-Arts architecture       0.82      0.55      0.66        42
#                      Neoclassicism, Greek Revival architecture       0.73      0.71      0.72        52
#                          Neoclassicism, Palladian architecture       0.77      0.50      0.61        34
#                                    Neoclassicism, Stalin Ampir       0.61      0.69      0.65        29
#                                           Novelty architecture       0.94      0.82      0.87        38
#             Renaissance_and_Colonialism, Colonial architecture       0.47      0.54      0.50        48
#   Renaissance_and_Colonialism, French Renaissance Architecture       0.75      0.40      0.52        15
#             Renaissance_and_Colonialism, Georgian architecture       0.51      0.50      0.51        38
#            Renaissance_and_Colonialism, Mannerist Architecture       0.36      0.31      0.33        13
# Renaissance_and_Colonialism, Northern Renaissance Architecture       0.06      0.09      0.07        11
#     Renaissance_and_Colonialism, Spanish Colonial Architecture       0.29      0.12      0.17        17
#  Renaissance_and_Colonialism, Spanish Renaissance Architecture       0.19      0.23      0.21        13
#                       Revivalism, Colonial Revival archtecture       0.40      0.27      0.32        22
#                             Revivalism, Edwardian architecture       0.50      0.43      0.46        28
#                           Revivalism, Orientalism Architecture       0.50      0.09      0.15        11
#                            Revivalism, Queen Anne architecture       0.76      0.86      0.81        72
#                       Revivalism, Russian Revival architecture       0.68      0.74      0.71        35
#                         Revivalism, Tudor Revival architecture       0.82      0.73      0.78        45
#                              Ukrainian classicism architecture       0.57      0.63      0.60        41
#                                    Ukrainian folk architecture       0.94      0.84      0.89        37
#
#                                                       accuracy                           0.63      1808
#                                                      macro avg       0.58      0.54      0.55      1808
#                                                   weighted avg       0.64      0.63      0.63      1808

# %%
class1_index = 17 
class2_index = 20 
true_labels = np.array(true_labels)
misclassified_class1_indices = np.where((true_labels == class1_index) & (predicted_labels == class2_index))[0]
misclassified_class2_indices = np.where((true_labels == class2_index) & (predicted_labels == class1_index))[0]

# %%
misclassified_class1_indices
# Out:
# array([417, 423, 425, 428, 433, 434, 435, 439, 448, 454, 461, 462, 466,
#        470, 471, 472, 473, 474, 483, 484, 486, 487, 490, 507, 514, 517,
#        519, 520, 525, 526, 527, 544, 561, 563, 564, 567, 573, 576, 578,
#        582, 584, 585, 586, 593, 602, 619], dtype=int64)

# %%
test_filenames = test_dataset.file_paths
for index in misclassified_class1_indices:
    print("Misclassified Image Path:", test_filenames[index])
# Out:
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1087391_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1151040_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q11722182_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q11920496_wd1.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1241004_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1244192_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1244218_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1244675_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1380108_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1423005_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1451602_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1451777_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1456842_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1508733_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1509528_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q15106938_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q15109670_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q15109671_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1549939_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1557230_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q15810551_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q15815698_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q15853818_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1711691_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1736223_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1742607_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q1751521_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q17606582_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q18007629_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q18616335_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q18649465_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q2244551_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q2733089_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q28059008_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q28061572_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q2867464_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q2942514_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q2957238_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q2984037_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q3580314_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q3580715_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q3583492_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q3583604_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q4729358_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q606976_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Gothic architecture\Q8350452_wd0.jpg

# %%
test_filenames = test_dataset.file_paths
for index in misclassified_class2_indices:
    print("Misclassified Image Path:", test_filenames[index])
# Out:
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\012973.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\013069.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\013366.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1032205_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1256448_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q12667945_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1272826_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q13098929_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1355728_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1371548_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1380085_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1387223_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1412770_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1455550_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q15109665_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1569333_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1572653_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q15742096_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q15806381_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q15806452_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q15809647_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q15848686_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q15953663_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1659709_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1679924_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1697136_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1728386_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1742714_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q17500436_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q18172002_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q1897749_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q19257510_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q2082940_wd1.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q210039_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q21480170_wd0.jpg
# Misclassified Image Path: D:/University/FinalDatasetSplited/test\Early_Christian_Medieval, Romanesque architecture\Q2212795_wd0.jpg
